# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('DF')

# %%
df.set_index('TITULO').head(10)
# Out:
#                              AÑO  DURACION (min)           GENERO  \
# TITULO
# (500) días juntos           2009              96          Romance
# ...Y si no, nos enfadamos   1974              92          Comedia
# 10 razones para odiarte     1999              97          Comedia
# 10.000 KM                   2014              98          Romance
# 100 metros                  2016             108            Drama
# 12                          2007             153            Drama
# 12 años de esclavitud       2013             133            Drama
# 12 monos                    1995             130  Ciencia ficción
# 120 pulsaciones por minuto  2017             143            Drama
# 127 horas                   2010              93            Drama
#
#                                         DIRECCION                  GUION  \
# TITULO
# (500) días juntos                       Marc Webb              Marc Webb
# ...Y si no, nos enfadamos        Marcello Fondato       Marcello Fondato
# ...

# %%
df.sort_values(['NOTA', 'VOTOS'], ascending=[False, False]).set_index('TITULO').head(10)
# Out:
#                         AÑO  DURACION (min)    GENERO             DIRECCION  \
# TITULO
# El padrino             1972             175     Drama  Francis Ford Coppola
# El padrino. Parte II   1974             200     Drama  Francis Ford Coppola
# La lista de Schindler  1993             195     Drama      Steven Spielberg
# Pulp Fiction           1994             153  Thriller     Quentin Tarantino
# Cadena perpetua        1994             142     Drama        Frank Darabont
# La vida es bella       1997             117   Comedia       Roberto Benigni
# El golpe               1973             129   Intriga       George Roy Hill
# Ciudad de Dios         2002             130     Drama    Fernando Meirelles
# Uno de los nuestros    1990             148  Thriller       Martin Scorsese
# Seven (Se7en)          1995             127  Thriller         David Fincher
#
#                                       GUION         PROTAGONISTA  \
# TITULO
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5040 entries, 0 to 5039
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   TITULO          5040 non-null   object
#  1   AÑO             5040 non-null   int64
#  2   DURACION (min)  5040 non-null   int64
#  3   GENERO          5040 non-null   object
#  4   DIRECCION       5040 non-null   object
#  5   GUION           5040 non-null   object
#  6   PROTAGONISTA    5040 non-null   object
#  7   PAIS            5040 non-null   object
#  8   NOTA            5040 non-null   float64
#  9   VOTOS           5040 non-null   int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 393.9+ KB

# %%
df.describe()
# Out:
#                AÑO  DURACION (min)         NOTA         VOTOS
# count  5040.000000     5040.000000  5040.000000    5040.00000
# mean   2003.621825      113.891865     6.561905   16216.44623
# std      12.983795       19.369748     0.537402   26417.90461
# min    1972.000000       90.000000     5.800000    1000.00000
# 25%    1995.000000      100.000000     6.100000    2129.00000
# 50%    2006.000000      110.000000     6.500000    5287.00000
# 75%    2014.000000      123.000000     6.900000   17101.50000
# max    2023.000000      450.000000     9.000000  202065.00000

# %% [markdown]
# UNO

# %%
sns.set(style='darkgrid')

# %%
df_media = df.groupby('AÑO')['NOTA'].mean().reset_index()

sns.set(style='darkgrid')

fig, ax = plt.subplots(figsize=(10, 5))
sns.lineplot(data=df_media, x='AÑO', y='NOTA')
ax.set_xlabel('AÑO')
ax.set_ylabel('NOTA')
ax.set_title('Media de notas por año')

ax.set_ylim(bottom=6)



plt.show()

# %%
df[df['AÑO'] == 1972].sort_values('NOTA',ascending=False).head(1)
# Out:
#           TITULO   AÑO  DURACION (min) GENERO             DIRECCION  \
# 1504  El padrino  1972             175  Drama  Francis Ford Coppola
#
#                      GUION   PROTAGONISTA            PAIS  NOTA   VOTOS
# 1504  Francis Ford Coppola  Marlon Brando  Estados Unidos   9.0  174133

# %%
df[df['AÑO'] == 2020].sort_values('NOTA',ascending=False).head(1)
# Out:
#         TITULO   AÑO  DURACION (min) GENERO       DIRECCION           GUION  \
# 1502  El padre  2020              97  Drama  Florian Zeller  Florian Zeller
#
#          PROTAGONISTA         PAIS  NOTA  VOTOS
# 1502  Anthony Hopkins  Reino Unido   7.7  15922

# %% [markdown]
# DOS

# %%
recuento_anual = df['AÑO'].value_counts().sort_index()


df_recuento = pd.DataFrame({'AÑO': recuento_anual.index, 'Recuento': recuento_anual.values})


sns.set(style='darkgrid')


fig, ax = plt.subplots(figsize=(10, 5))
sns.lineplot(data=df_recuento, x='AÑO', y='Recuento')
ax.set_xlabel('AÑO')
ax.set_ylabel('PELICULAS')
ax.set_title('Películas por año')

plt.show()

# %%
df['AÑO'].value_counts().head(1)
# Out:
# 2014    183
# Name: AÑO, dtype: int64

# %%
df_odenado = df.sort_values(['NOTA', 'VOTOS'], ascending=[False, False]).set_index('TITULO')

# %%
df_odenado[df_odenado['AÑO'] == 2014].head(3)
# Out:
#                    AÑO  DURACION (min)           GENERO          DIRECCION  \
# TITULO
# Interstellar      2014             169  Ciencia ficción  Christopher Nolan
# Whiplash          2014             103            Drama    Damien Chazelle
# Relatos salvajes  2014             119          Comedia     Damián Szifrón
#
#                               GUION         PROTAGONISTA            PAIS  \
# TITULO
# Interstellar      Christopher Nolan  Matthew McConaughey  Estados Unidos
# Whiplash            Damien Chazelle         Miles Teller  Estados Unidos
# Relatos salvajes     Damián Szifrón        Ricardo Darín       Argentina
#
#                   NOTA   VOTOS
# TITULO
# Interstellar       7.9  101296
# Whiplash           7.8   65460
# Relatos salvajes   7.7   67160

# %% [markdown]
# TRES

# %%
media_duraciones = df.groupby('AÑO')['DURACION (min)'].mean().reset_index()

sns.set(style='darkgrid')


fig, ax = plt.subplots(figsize=(10, 5))
sns.lineplot(data=media_duraciones, x='AÑO', y='DURACION (min)')
ax.set_xlabel('AÑO')
ax.set_ylabel('MINUTOS')
ax.set_title('Media de duración en los últimos 5 años')
plt.xlim(2018,2023)

plt.show()

# %%
df.sort_values(['DURACION (min)'], ascending=False).set_index('TITULO').head(3)
# Out:
#                                   AÑO  DURACION (min) GENERO  \
# TITULO
# Sátántangó                       1994             450  Drama
# Novecento (1900)                 1976             314  Drama
# Luis II de Baviera, el rey loco  1973             264  Drama
#
#                                            DIRECCION                GUION  \
# TITULO
# Sátántangó                                 Béla Tarr            Béla Tarr
# Novecento (1900)                 Bernardo Bertolucci  Bernardo Bertolucci
# Luis II de Baviera, el rey loco     Luchino Visconti     Luchino Visconti
#
#                                      PROTAGONISTA     PAIS  NOTA  VOTOS
# TITULO
# Sátántangó                             Mihály Víg  Hungría   8.0   1905
# Novecento (1900)                 Gérard Depardieu   Italia   8.2  19461
# Luis II de Baviera, el rey loco     Helmut Berger   Italia   7.4   1831

# %% [markdown]
# CUATRO

# %%
sns.set(style='darkgrid')

fig, ax = plt.subplots(figsize=(10, 5))
sns.regplot(data=df, x='NOTA', y='DURACION (min)', scatter_kws={'color': 'yellow', 'alpha': 0.7})
ax.set_xlabel('NOTA')
ax.set_ylabel('MINUTOS')
ax.set_title('Correlación entre duración y nota')
ax.set_ylim(0, 300)

plt.show()

# %%
df.sort_values(by=['NOTA', 'DURACION (min)'], ascending=(False, False)).head(3)
# Out:
#                      TITULO   AÑO  DURACION (min) GENERO  \
# 1504             El padrino  1972             175  Drama
# 1505   El padrino. Parte II  1974             200  Drama
# 2736  La lista de Schindler  1993             195  Drama
#
#                  DIRECCION                 GUION   PROTAGONISTA  \
# 1504  Francis Ford Coppola  Francis Ford Coppola  Marlon Brando
# 1505  Francis Ford Coppola  Francis Ford Coppola      Al Pacino
# 2736      Steven Spielberg      Steven Spielberg    Liam Neeson
#
#                 PAIS  NOTA   VOTOS
# 1504  Estados Unidos   9.0  174133
# 1505  Estados Unidos   8.9  138933
# 2736  Estados Unidos   8.7  174440

# %% [markdown]
# CINCO

# %%
df['GENERO'].nunique()
# Out:
# 16

# %%
df['GENERO'].value_counts()
# Out:
# Drama              2228
# Comedia             604
# Thriller            501
# Romance             233
# Animación           220
# Acción              201
# Intriga             201
# Ciencia ficción     190
# Terror              168
# Aventuras           155
# Fantástico          124
# Bélico               86
# Musical              54
# Western              51
# Cine negro           21
# Infantil              3
# Name: GENERO, dtype: int64

# %%
mayor_nota_por_genero = df.groupby('GENERO')['NOTA'].idxmax()
df.loc[mayor_nota_por_genero]
# Out:
#                                            TITULO   AÑO  DURACION (min)  \
# 2030                                    Gladiator  2000             150
# 1664                          El viaje de Chihiro  2001             124
# 901                      Dersu Uzala (El cazador)  1975             141
# 260                                Apocalypse Now  1979             153
# 174                     Alien, el octavo pasajero  1979             116
# 659                                     Chinatown  1974             131
# 2925                             La vida es bella  1997             117
# 1504                                   El padrino  1972             175
# 1613  El señor de los anillos: El retorno del rey  2003             201
# 3753                                   Paddington  2014              95
# 1312                                     El golpe  1973             129
# 3850                          Pink Floyd: El muro  1982              99
# ...

# %%
sns.set(style='darkgrid')

conteo_genero = df['GENERO'].value_counts()

fig, ax = plt.subplots(figsize=(10, 5))
sns.barplot(x=conteo_genero.index, y=conteo_genero.values)
ax.set_xlabel('GENERO')
ax.set_ylabel('PELICULAS')
ax.set_title('Películas por género')

plt.xticks(rotation=45);

# %% [markdown]
# SEIS

# %%
df['NOTA'].mean().__round__(2)
# Out:
# 6.56

# %%
df.groupby('GENERO')['NOTA'].mean().round(2).sort_values(ascending=False)
# Out:
# GENERO
# Cine negro         6.75
# Animación          6.71
# Bélico             6.70
# Drama              6.64
# Musical            6.59
# Western            6.59
# Intriga            6.52
# Thriller           6.50
# Ciencia ficción    6.49
# Aventuras          6.48
# Comedia            6.48
# Romance            6.47
# Fantástico         6.45
# Acción             6.39
# Terror             6.30
# Infantil           5.97
# Name: NOTA, dtype: float64

# %%
sns.set(style='darkgrid')

media_nota_por_genero = df.groupby('GENERO')['NOTA'].mean()

fig, ax = plt.subplots(figsize=(10, 5))
sns.barplot(x=media_nota_por_genero.index, y=media_nota_por_genero.values)
ax.set_xlabel('GENERO')
ax.set_ylabel('NOTA')
ax.set_title('Media de nota por género')
ax.set_ylim(5.75)

plt.xticks(rotation=45);

# %% [markdown]
# SIETE

# %%
western_data = df[df['GENERO'] == 'Western']

sns.set(style='darkgrid')
sns.kdeplot(data=western_data['AÑO'], fill=True)


plt.xlabel('AÑO')
plt.ylabel('DENSIDAD')
plt.title('Densidad del género Western por año')
plt.xlim(1972,2023)

plt.show()

# %%
western_data = df[df['GENERO'] == 'Western']

western_data['AÑO'].value_counts().head(3)
# Out:
# 1976    4
# 1973    3
# 2014    3
# Name: AÑO, dtype: int64

# %%
df.loc[(df['GENERO'] == 'Western') & (df['AÑO'] == 1976)]
# Out:
#                                         TITULO   AÑO  DURACION (min)   GENERO  \
# 1304                        El fuera de la ley  1976             135  Western
# 1709                       El último pistolero  1976              99  Western
# 2901  La venganza de un hombre llamado Caballo  1976             125  Western
# 3481                                  Missouri  1976             126  Western
#
#            DIRECCION           GUION    PROTAGONISTA            PAIS  NOTA  \
# 1304  Clint Eastwood  Clint Eastwood  Clint Eastwood  Estados Unidos   7.4
# 1709      Don Siegel      Don Siegel      John Wayne  Estados Unidos   6.6
# 2901  Irvin Kershner  Irvin Kershner  Richard Harris  Estados Unidos   5.8
# 3481     Arthur Penn     Arthur Penn   Marlon Brando  Estados Unidos   6.0
#
#       VOTOS
# 1304  10115
# 1709   2340
# 2901   1151
# 3481   1210

# %% [markdown]
# OCHO

# %%
df['DIRECCION'].value_counts().head(5)
# Out:
# Woody Allen         33
# Clint Eastwood      32
# Steven Spielberg    27
# Martin Scorsese     23
# Ridley Scott        21
# Name: DIRECCION, dtype: int64

# %%
df.loc[df['DIRECCION'] == 'Woody Allen'].sort_values(['NOTA'], ascending=False).head(3)
# Out:
#                 TITULO   AÑO  DURACION (min)   GENERO    DIRECCION  \
# 3319         Manhattan  1979              96  Comedia  Woody Allen
# 243         Annie Hall  1977              94  Romance  Woody Allen
# 893   Delitos y faltas  1989             104    Drama  Woody Allen
#
#             GUION PROTAGONISTA            PAIS  NOTA  VOTOS
# 3319  Woody Allen  Woody Allen  Estados Unidos   8.1  54359
# 243   Woody Allen  Woody Allen  Estados Unidos   8.0  72912
# 893   Woody Allen  Woody Allen  Estados Unidos   7.9  24711

# %% [markdown]
# NUEVE

# %%
df.groupby('DIRECCION')['DURACION (min)'].mean().sort_values(ascending=False).head(3)
# Out:
# DIRECCION
# Ronald F. Maxwell    248.0
# Mariano Llinás       245.0
# Jacques Rivette      238.0
# Name: DURACION (min), dtype: float64

# %%
df.loc[df['DIRECCION'] == 'Steven Spielberg'].sort_values(['DURACION (min)'], ascending=False).head(3)
# Out:
#                       TITULO   AÑO  DURACION (min)    GENERO  \
# 2736   La lista de Schindler  1993             195     Drama
# 4086  Salvar al soldado Ryan  1998             170    Bélico
# 3538                  Munich  2005             164  Thriller
#
#              DIRECCION             GUION   PROTAGONISTA            PAIS  NOTA  \
# 2736  Steven Spielberg  Steven Spielberg    Liam Neeson  Estados Unidos   8.7
# 4086  Steven Spielberg  Steven Spielberg      Tom Hanks  Estados Unidos   7.8
# 3538  Steven Spielberg  Steven Spielberg  Javier Cámara          España   7.1
#
#        VOTOS
# 2736  174440
# 4086  141085
# 3538   55836

# %%
df.loc[df['DIRECCION'] == 'Ronald F. Maxwell'].sort_values(['DURACION (min)'], ascending=False)
# Out:
#           TITULO   AÑO  DURACION (min)  GENERO          DIRECCION  \
# 2018  Gettysburg  1993             248  Bélico  Ronald F. Maxwell
#
#                   GUION  PROTAGONISTA            PAIS  NOTA  VOTOS
# 2018  Ronald F. Maxwell  Tom Berenger  Estados Unidos   6.6   1286

# %% [markdown]
# DIEZ

# %%
df.groupby('DIRECCION')['NOTA'].mean().sort_values(ascending=False).head(3)
# Out:
# DIRECCION
# Sergio Leone            8.30
# Joseph L. Mankiewicz    8.10
# Lee Unkrich             7.95
# Name: NOTA, dtype: float64

# %%
df.loc[df['DIRECCION'] == 'Sergio Leone'].sort_values(['NOTA'], ascending=False)
# Out:
#                         TITULO   AÑO  DURACION (min) GENERO     DIRECCION  \
# 5031  Érase una vez en América  1984             225  Drama  Sergio Leone
#
#              GUION    PROTAGONISTA            PAIS  NOTA  VOTOS
# 5031  Sergio Leone  Robert De Niro  Estados Unidos   8.3  57572

# %% [markdown]
# ONCE

# %%
df.groupby('DIRECCION')['VOTOS'].mean().sort_values(ascending=False).head(3)
# Out:
# DIRECCION
# James McTeigue       131061.0
# Quentin Tarantino    117189.2
# Jerry Zucker         112793.0
# Name: VOTOS, dtype: float64

# %%
df.groupby('DIRECCION')['VOTOS'].sum().sort_values(ascending=False).head(3)
# Out:
# DIRECCION
# Steven Spielberg     1864810
# Clint Eastwood       1257169
# Quentin Tarantino    1171892
# Name: VOTOS, dtype: int64

# %%
df.loc[df['DIRECCION'] == 'James McTeigue'].sort_values(['VOTOS'], ascending=False)
# Out:
#              TITULO   AÑO  DURACION (min)           GENERO       DIRECCION  \
# 4830  V de Vendetta  2005             132  Ciencia ficción  James McTeigue
#
#                GUION     PROTAGONISTA            PAIS  NOTA   VOTOS
# 4830  James McTeigue  Natalie Portman  Estados Unidos   7.5  131061

# %% [markdown]
# DOCE

# %%
df.groupby('GUION')['NOTA'].mean().sort_values(ascending=False).head(3)
# Out:
# GUION
# Fernando Meirelles,     8.4
# Sergio Leone            8.3
# Joseph L. Mankiewicz    8.1
# Name: NOTA, dtype: float64

# %%
df.loc[df['DIRECCION'] == 'Fernando Meirelles'].sort_values(['NOTA'], ascending=False).head(3)
# Out:
#                  TITULO   AÑO  DURACION (min)    GENERO           DIRECCION  \
# 677      Ciudad de Dios  2002             130     Drama  Fernando Meirelles
# 1393  El jardinero fiel  2005             128  Thriller  Fernando Meirelles
# 3165      Los dos papas  2019             126     Drama  Fernando Meirelles
#
#                     GUION         PROTAGONISTA         PAIS  NOTA   VOTOS
# 677   Fernando Meirelles,  Alexandre Rodrigues       Brasil   8.4  127731
# 1393   Fernando Meirelles        Ralph Fiennes  Reino Unido   7.3   51259
# 3165   Fernando Meirelles       Carey Mulligan  Reino Unido   6.8   15414

# %% [markdown]
# TRECE

# %%
df.groupby('PROTAGONISTA')['NOTA'].mean().sort_values(ascending=False).head(3)
# Out:
# PROTAGONISTA
# Alexandre Rodrigues    8.4
# Ray Liotta             8.4
# Maksim Munzuk          8.3
# Name: NOTA, dtype: float64

# %%
df.loc[df['PROTAGONISTA'] == 'Ray Liotta'].sort_values(['NOTA'], ascending=False)
# Out:
#                    TITULO   AÑO  DURACION (min)    GENERO        DIRECCION  \
# 4817  Uno de los nuestros  1990             148  Thriller  Martin Scorsese
#
#                 GUION PROTAGONISTA            PAIS  NOTA   VOTOS
# 4817  Martin Scorsese   Ray Liotta  Estados Unidos   8.4  113022

# %% [markdown]
# CATORCE

# %%
df['PAIS'].value_counts().head(5)
# Out:
# Estados Unidos    2267
# Reino Unido        529
# España             472
# Francia            408
# Japón              179
# Name: PAIS, dtype: int64

# %%
country_counts = df['PAIS'].value_counts().head(5)


country_counts.plot(kind='pie', figsize=(8, 8), autopct='%1.1f%%')

plt.title('Películas por país')
plt.ylabel('')

plt.show()

# %% [markdown]
# QUINCE

# %%
sns.set(style='darkgrid')

fig, ax = plt.subplots(figsize=(10, 5))
sns.regplot(data=df, x='NOTA', y='VOTOS', scatter_kws={'color': 'yellow', 'alpha': 0.7})
ax.set_xlabel('NOTA')
ax.set_ylabel('VOTOS')
ax.set_title('Correlación entre nota y votos')
ax.set_ylim(0, 100000)

plt.show()
